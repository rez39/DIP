# %%
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
import math 
import time
import cmath
NaN=np.NaN
from skimage.color import label2rgb
from IPython.display import Image 
import random

# %%
img = cv2.imread('C:/Users/91709/Desktop/DIP/assignment-3-rez39/images/thumb_print.jpg',0)
print("Rows, Columns, Channels:",img.shape)
plt.figure(figsize=[10,10])
plt.imshow(img,cmap='gray')
plt.axis('off')
plt.title('Original Image')
ret,binaryimage = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
plt.figure(figsize=[10,10])
plt.imshow(binaryimage,cmap='gray')
plt.axis('off')
plt.title('Binary Image')
plt.show()
# Out:
# Rows, Columns, Channels: (480, 400)

# %%
def skeletonize(im,s1,s2,output):
    img=im.copy()
    M,N=img.shape
    m,n=s1.shape
    for i in range(1,M-1):
        for j in range(1,N-1):
            im=img[i-1:i+2,j-1:j+2]
            if(np.sum(np.bitwise_xor(im[~(s1==2)],s1[~(s1==2)]))==0):
                output[i][j]=0
                
    for i in range(1,M-1):
        for j in range(1,N-1):
            im=img[i-1:i+2,j-1:j+2]
            if(np.sum(np.bitwise_xor(im[~(s2==2)],s2[~(s2==2)]))==0):
                output[i][j]=0
                
    s1=np.rot90(s1,1)
    s2=np.rot90(s2,1)
    if np.sum(img-output)==0:
        return output
    img=output.copy()
    skeletonize(img,s1,s2,output)

# %%
s1= np.array([[0,0,0],[2,255,2],[255,255,255]])
s2=np.array([[2,0,0],[255,255,0],[2,255,2]])
output=binaryimage.copy()
skeletonize(binaryimage,s1,s2,output)
plt.figure(figsize=[10,10])
plt.imshow(output,cmap='gray')
plt.axis('off')
plt.title('Skeleton Image')
plt.show()

# %%
img = cv2.imread('C:/Users/91709/Desktop/DIP/assignment-3-rez39/images/dragon.png',0)
print("Rows, Columns, Channels:",img.shape)
plt.figure(figsize=[10,10])
plt.subplot(1,3,1)
plt.imshow(img,cmap='gray')
plt.axis('off')
plt.title('Original Image')
ret,binaryimage = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
plt.subplot(1,3,2)
plt.imshow(binaryimage,cmap='gray')
plt.axis('off')
plt.title('Binary Image')
plt.subplot(1,3,3)
output=binaryimage.copy()
skeletonize(binaryimage,s1,s2,output)
plt.imshow(output,cmap='gray')
plt.axis('off')
plt.title('Skeleton Image')
img = cv2.imread('C:/Users/91709/Desktop/DIP/assignment-3-rez39/images/butterfly.jpg',0)
print("Rows, Columns, Channels:",img.shape)
plt.figure(figsize=[10,10])
plt.subplot(1,3,1)
plt.imshow(img,cmap='gray')
plt.axis('off')
plt.title('Original Image')
ret,binaryimage = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
plt.subplot(1,3,2)
plt.imshow(binaryimage,cmap='gray')
plt.axis('off')
plt.title('Binary Image')
plt.subplot(1,3,3)
output=binaryimage.copy()
skeletonize(binaryimage,s1,s2,output)
plt.imshow(output,cmap='gray')
plt.axis('off')
plt.title('Skeleton Image')
img = cv2.imread('C:/Users/91709/Desktop/DIP/assignment-3-rez39/images/keyhole.jpg',0)
print("Rows, Columns, Channels:",img.shape)
plt.figure(figsize=[10,10])
plt.subplot(1,3,1)
plt.imshow(img,cmap='gray')
plt.axis('off')
plt.title('Original Image')
ret,binaryimage = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
plt.subplot(1,3,2)
plt.imshow(binaryimage,cmap='gray')
plt.axis('off')
plt.title('Binary Image')
plt.subplot(1,3,3)
output=binaryimage.copy()
skeletonize(binaryimage,s1,s2,output)
plt.imshow(output,cmap='gray')
plt.axis('off')
plt.title('Skeleton Image')
plt.show()
# Out:
# Rows, Columns, Channels: (300, 300)
# Rows, Columns, Channels: (500, 500)
# Rows, Columns, Channels: (626, 626)

# %% [markdown]
# ## part1.4
# Images are shown above
# ## part 1.2
# Here, S1 and S2 are structuring elements that are used to identify triangular structures , and also small
# L shaped structures .

# %%
#part 1.2
def skeletonizepassing(im,s1):
    img=im.copy()
    M,N=img.shape
    m,n=s1.shape
    for i in range(1,M-1):
        for j in range(1,N-1):
            im=img[i-1:i+2,j-1:j+2]
            if(np.sum(np.bitwise_xor(im[~(s1==2)],s1[~(s1==2)]))==0):
                img[i][j]=0
    return img
s1= np.array([[0,0,0],[2,255,2],[255,255,255]])
s2=np.array([[2,0,0],[255,255,0],[2,255,2]])    
img = cv2.imread('C:/Users/91709/Desktop/DIP/assignment-3-rez39/images/dragon.png',0)
print("Rows, Columns, Channels:",img.shape)
plt.figure(figsize=[10,10])
plt.subplot(3,3,1)
plt.imshow(img,cmap='gray')
plt.axis('off')
plt.title('Original Image')
ret,binaryimage = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
plt.subplot(3,3,2)
plt.imshow(binaryimage,cmap='gray')
plt.axis('off')
plt.title('Binary Image')
plt.subplot(3,3,3)
output=skeletonizepassing(binaryimage,s1)
plt.imshow(output,cmap='gray')
plt.axis('off')
plt.title('Skeleton Image first passing')
plt.subplot(3,3,4)
output=skeletonizepassing(output,s2)
plt.imshow(output,cmap='gray')
plt.axis('off')
plt.title('Skeleton Image second passing')
s1=np.rot90(s1,1)
s2=np.rot90(s2,1)
plt.subplot(3,3,5)
output=skeletonizepassing(output,s1)
plt.imshow(output,cmap='gray')
plt.axis('off')
plt.title('Skeleton Image third passing')
plt.subplot(3,3,6)
output=skeletonizepassing(output,s2)
plt.imshow(output,cmap='gray')
plt.axis('off')
plt.title('Skeleton Image fourth passing')
s1=np.rot90(s1,1)
s2=np.rot90(s2,1)
plt.subplot(3,3,7)
output=skeletonizepassing(output,s1)
plt.imshow(output,cmap='gray')
plt.axis('off')
plt.title('Skeleton Image fifth passing')
plt.subplot(3,3,8)
output=skeletonizepassing(output,s2)
plt.imshow(output,cmap='gray')
plt.axis('off')
plt.title('Skeleton Image sixth passing')
s1=np.rot90(s1,1)
plt.subplot(3,3,9)
output=skeletonizepassing(output,s1)
plt.imshow(output,cmap='gray')
plt.axis('off')
plt.title('Skeleton Image seventh passing')
plt.show()
# Out:
# Rows, Columns, Channels: (300, 300)

# %% [markdown]
# ## Part 1.3
# We might need to pass the structure several times , because the object in image can be rotated too .
# Its not orientation invariant, so we need to rotate the structure element in all possible directions .

# %%
#question2 
img = cv2.imread('C:/Users/91709/Desktop/DIP/assignment-3-rez39/images/kidney.jpg',0)
print("Rows, Columns, Channels:",img.shape)
plt.figure(figsize=[10,10])
plt.imshow(img,cmap='gray')
plt.axis('off')
plt.title('Original Image')
plt.show()
# Out:
# Rows, Columns, Channels: (512, 512)

# %%
def hex_to_rgb(hex):
    hex = hex.lstrip('#')
    hlen = len(hex)
    return tuple(int(hex[i:i+int(hlen/3)], 16) for i in range(0, hlen, int(hlen/3) ))

### morphology

def image2binaryIm(input_image):
    kernel = np.ones((8,8), np.uint8)       # set kernel as 5x5 matrix from numpy

    # Create erosion and dilation image from the original image
    
    # Convert to binary

    (thresh, im_bw) = cv2.threshold(input_image, 130, 255, cv2.THRESH_BINARY)
    
    dilation_image = cv2.erode(im_bw, kernel, iterations=1)
    dilation_image = cv2.dilate(dilation_image, kernel, iterations=1)
    dilation_image= dilation_image.astype(np.uint8)
    return dilation_image




# This function returns 8 connected nieghbours of an element in the form of a list.

def Get_Neighbor_8_Connected(x_coordinate, y_coordinate, row, col, image):
    Neighbor = []
    FinalNeighbors = []
    Neighbor.append([x_coordinate, y_coordinate+1])
    Neighbor.append([x_coordinate, y_coordinate-1])
    Neighbor.append([x_coordinate+1, y_coordinate])
    Neighbor.append([x_coordinate-1, y_coordinate])
    Neighbor.append([x_coordinate+1, y_coordinate+1])
    Neighbor.append([x_coordinate-1, y_coordinate-1])
    Neighbor.append([x_coordinate-1, y_coordinate+1])
    Neighbor.append([x_coordinate+1, y_coordinate-1])

    for i in range(len(Neighbor)):
        x, y = Neighbor[i]
        if (x >= 0 and x < row and y >= 0 and y < col and image[x][y] > 0):
            FinalNeighbors.append([x, y])
    Neighbor = []

    return FinalNeighbors


# This function returns 4 connected nieghbours of an element in the form of a list.
def Get_Neighbor_4_Connected(x_coordinate, y_coordinate, row, col, image):
    Neighbor = []
    FinalNeighbors = []
    Neighbor.append([x_coordinate, y_coordinate+1])
    Neighbor.append([x_coordinate, y_coordinate-1])
    Neighbor.append([x_coordinate+1, y_coordinate])
    Neighbor.append([x_coordinate-1, y_coordinate])
    for i in range(len(Neighbor)):
        x, y = Neighbor[i]
        if (x >= 0 and x < row and y >= 0 and y < col and image[x][y] > 0):
            FinalNeighbors.append([x, y])
    Neighbor = []

    return FinalNeighbors


# This function returns 8 connected nieghbours of an element in matrix. It returns [-1,array of labels of neighbours] if all
# neighbours have no label till now and [0,max(labels)] if neighbours have labels.
def Get_Neighbor_Label(array, labels):
    CheckNeigbor = []
    for i in range(len(array)):
        x, y = array[i]
        CheckNeigbor.append(labels[x][y])
    if max(CheckNeigbor) == -1:
        return [1, 0]
    else:
        LabelledNeighbors = [x for x in CheckNeigbor if x != -1]
        LabelledNeighbors = list(set(LabelledNeighbors))
        if len(LabelledNeighbors) == 1:
            return [0, max(CheckNeigbor)]
        else:
            return [-1, LabelledNeighbors]
def ccl(ImageBinary, row, col, var, flag):

    SameLabels = []
    LabelCount = 50
    Labels = np.zeros((row, col)) - 1

    for i in range(row):
        for j in range(col):
            if ImageBinary[i][j] > 0:
                if var == 8:
                    n = Get_Neighbor_8_Connected(i, j, row, col, ImageBinary)
                else:
                    n = Get_Neighbor_4_Connected(i, j, row, col, ImageBinary)
                if len(n) > 0:
                    l = Get_Neighbor_Label(n, Labels)

                    if l[0] == 1:
                        LabelCount = LabelCount + 1
                        Labels[i][j] = LabelCount
                        for k in range(len(n)):
                            [c1, c2] = n[k]
                            Labels[c1, c2] = LabelCount

                    elif l[0] == 0:
                        Labels[i][j] = l[1]
                        for k in range(len(n)):
                            [c1, c2] = n[k]
                            Labels[c1, c2] = l[1]
                    elif l[0] == -1:
                        same = l[1]
                        SameLabels.append(same)
                        for m in range(len(same)):
                            Labels[Labels == same[m]] = min(same)
                        Labels[c1, c2] = min(same)
                elif len(n) == 0:
                    LabelCount = LabelCount + 1
                    Labels[i][j] = LabelCount

    Labels[Labels < 0] = 0
    LabelList = np.unique(Labels)
    LabelList = np.delete(LabelList, 0)
    LabelList = sorted(LabelList)
    RemoveIndex = []
    
    # Remove labels that are not present in image
    for i in range(len(LabelList)):
        num = (Labels == LabelList[i]).sum()
        if num == 0:
            RemoveIndex.append(LabelList[i])

    for i in range(len(RemoveIndex)):
        LabelList.remove(RemoveIndex[i])

    if flag == 1 :

        indices = []
        threshold = 100    
        RemoveIndex = []
        for i in range(len(LabelList)):
            lab = LabelList[i]
            indx, indy = np.where(Labels==lab)
            if len(indx) <= threshold :
                for j in range(len(indx)) :
                    x = indx[j]
                    y = indy[j]
                    indices.append([x,y])
        
        for j in range(len(indices)) :
            x, y = indices[j]
            ImageBinary[x][y] = 255

        ImageBinary[ImageBinary>0] = 255
        return ImageBinary

    Labels = Labels.astype(np.uint8)
    div = len(LabelList)
    col = 0
    
    from random import randint
    colors = []
    rgbCol = []
    for i in range(div):
        # while True :
        colors='#%06X' % randint(0, 0xFFFFFF)
        rgb = hex_to_rgb(colors)
        r, g, b = rgb
        # if r >= 200 and g >= 200 and b >= 200 :
        #     break
        rgbCol.append(rgb)

    # Convert to color image
    colorIm = cv2.cvtColor(Labels, cv2.COLOR_GRAY2BGR)

    for i in range(len(LabelList)) :
        color1, color2, color3 = rgbCol[i]
        lab = int(LabelList[i])
        b = colorIm[:,:,0]
        g = colorIm[:,:,1]
        r = colorIm[:,:,2]
        r[r==lab] = color1
        g[g==lab] = color2
        b[b==lab] = color3
        colorIm[:,:,0] = b
        colorIm[:,:,1] = g
        colorIm[:,:,2] = r

    # Return list of labels and image matrix where each element is label of each component

    return colorIm
ImageBinary=image2binaryIm(img)
row=ImageBinary.shape[0]
col=ImageBinary.shape[1]
var=4
OutputIm = ccl(ImageBinary, row, col, var, 1)
OutputIm = ccl(OutputIm, row, col, var, 0)
plt.figure(figsize=[10,10])
plt.imshow(OutputIm)
plt.axis('off')
plt.title('Output Image')
plt.show()

# %%
#question 4
def EulerNumbers(L):
    '''
    For a label matrix L containing nonnegative integers, returns a vector e
    such that e[k-1] is the 4-connected Euler number of the binary image (L ==
    k), from k = 1 to max(L).

    Adapted from:
    https://blogs.mathworks.com/steve/2014/10/02/lots-and-lots-of-euler-numbers/
    Accessed on 5.4.2019.
    '''

    Lp = np.pad(L, ((1,0), (1,0)), 'constant')

    I_NW = Lp[ :-1,  :-1];
    I_N  = Lp[ :-1, 1:  ];
    I_W  = Lp[1:  ,  :-1];

    is_upstream_convexity = np.logical_and(L,(L != I_N));
    is_upstream_convexity = np.logical_and(is_upstream_convexity, (L != I_NW));
    is_upstream_convexity = np.logical_and(is_upstream_convexity,  (L != I_W));

    is_upstream_concavity = np.logical_and(L,(L != I_NW));
    is_upstream_concavity = np.logical_and(is_upstream_concavity, (L == I_N));
    is_upstream_concavity = np.logical_and(is_upstream_concavity, (L == I_W));

    upstream_convexity_labels = L[is_upstream_convexity];
    upstream_concavity_labels = L[is_upstream_concavity];

    total_upstream_convexities = np.bincount(upstream_convexity_labels)[1:] #Discard the zero bin, which is the background.
    total_upstream_concavities = np.bincount(upstream_concavity_labels)[1:]
    if len(total_upstream_convexities)>len(total_upstream_concavities):
        return total_upstream_convexities[0:len(total_upstream_concavities)]-total_upstream_concavities;
    else:
        return total_upstream_convexities-total_upstream_concavities[0:len(total_upstream_convexities)];


#Load the image
BwI = cv2.imread('C:/Users/91709/Desktop/DIP/assignment-3-rez39/images/objects.png', cv2.IMREAD_GRAYSCALE)
_,BwI = cv2.threshold(BwI,130,255,cv2.THRESH_BINARY)
plt.figure(figsize=[10,10])
plt.imshow(BwI,cmap='gray')
plt.axis('off')
plt.title('Binary Image')
plt.show()
#Label all the connected components
_, L = cv2.connectedComponents(BwI)

#Compute all the Euler numbers
e = EulerNumbers(L)

# All the regions with no holes will have an Euler number of 1. Regions with one hole
# will have an Euler number of 0. Two holes -> -1 etc. 

num_no_holes = np.sum(e==1)
num_single_hole = np.sum(e==0)
num_two_holes = np.sum(e==-1)
num_three_holes = np.sum(e==-2)
num_more_holes = np.sum(e<-2)

print('Number of objects without holes : %d'%num_no_holes)
print('Number of objects with single hole : %d'%num_single_hole)
print('Number of objects with two holes : %d'%num_two_holes)
print('Number of objects with three holes : %d'%num_three_holes)
print('Number of objects with more than three holes: %d'%num_more_holes)

## Example, colourcode all objects by their amount of holes

Euler2Numholes = lambda e : abs(e-1)

#Label each region by the number of holes it has + 1.
# +1 so the holeless ones won't dissappear.
L_holecounts = np.zeros(L.shape, dtype=np.int32)
for i in range(1, np.max(L)):
    L_holecounts[L == i] = Euler2Numholes(e[i-1])+1

#Spread the small range to [0,255]
plot_L = cv2.normalize(L_holecounts, None, 0, 255, cv2.NORM_MINMAX, dtype=cv2.CV_8UC1) 
#Note that this will break when there are more than 255 labels. The colormap only works with uint8.

#Colormap it
plot_L = cv2.applyColorMap(plot_L, cv2.COLORMAP_JET)
plt.figure(figsize=[10,10])
plt.imshow(plot_L)
plt.axis('off')
plt.title('Output Image')
plt.show()
# Out:
# Number of objects without holes : 21
# Number of objects with single hole : 2
# Number of objects with two holes : 4
# Number of objects with three holes : 0
# Number of objects with more than three holes: 0

# %% [markdown]
# # question 6
#
# ## part1:
# We use upsampling with a factor k for increasing the size of the label image. The upsampled image points are interpolated using relevant techniques like Nearest Neighbour, Bilinear Upsampling, hermite upsampling, bell upsampling or other techniques which seem the best fit
# ## part2
# We use Affine Transformation or homographical operation a 3x3 matrix for each pixel on the image to obtain the rotation image. Both preserve shapes and connectivity pretty well and hence seem the better option

# %%
#question 7
def rotImage(img,angle,retain):
    m,n=img.shape
    A=np.array([[np.cos(np.deg2rad(angle)),-np.sin(np.deg2rad(angle))],[np.sin(np.deg2rad(angle)),np.cos(np.deg2rad(angle))]])
    #print(A)
    if retain==True:
        output=np.zeros([m,n])
        for i in range(m):
            for j in range(n):
                x=np.matmul(A,np.array([[i-math.floor(m/2)],[j-math.floor(n/2)]]))
                x0=int(np.round(x[0]+math.floor(m/2)))
                x1=int(np.round(x[1]+math.floor(n/2)))
                if x0<m and x1<n and x0>=0 and x1>=0:
                    output[x0,x1]=img[i,j]
    if retain==False:
        max0=[]
        max1=[]
        for i in range(m):
            for j in range(n):
                x=np.matmul(A,np.array([[i-math.floor(m/2)],[j-math.floor(n/2)]]))
                max0.append(int(np.round(x[0]+math.floor(m/2))))
                max1.append(int(np.round(x[1]+math.floor(n/2))))
        min0=abs(int(min(max0)))
        min1=abs(int(min(max1)))
        #print(max(max0)+min0,max(max1)+min1)
        output=np.zeros([int(max(max0)+min0)+1,int(max(max1)+min1)+1])
        for i in range(m):
            for j in range(n):
                x=np.matmul(A,np.array([[i-math.floor(m/2)],[j-math.floor(n/2)]]))
                x0=int(np.round(x[0]+math.floor(m/2)))+min0
                x1=int(np.round(x[1]+math.floor(n/2)))+min1
                if x0>=0 and x1>=0:
                    output[x0,x1]=img[i,j]
                
    return output

# %%
img = cv2.imread('C:/Users/91709/Desktop/DIP/assignment-3-rez39/images/thumb_print.jpg',0)
print("Rows, Columns, Channels:",img.shape)
plt.figure(figsize=[10,10])
plt.subplot(1,3,1)
plt.imshow(img,cmap='gray')
plt.axis('off')
plt.title('Original Image')
rotatedimage=rotImage(img,30,True)
plt.subplot(1,3,2)
plt.imshow(rotatedimage,cmap='gray')
plt.axis('off')
plt.title('30 Rotated Image with same dim')
rotatedimage=rotImage(img,30,False)
plt.subplot(1,3,3)
plt.imshow(rotatedimage,cmap='gray')
plt.axis('off')
plt.title('30 Rotated Image with new dim')
plt.figure(figsize=[10,10])
plt.subplot(1,3,1)
plt.imshow(img,cmap='gray')
plt.axis('off')
plt.title('Original Image')
rotatedimage=rotImage(img,45,True)
plt.subplot(1,3,2)
plt.imshow(rotatedimage,cmap='gray')
plt.axis('off')
plt.title('45 Rotated Image with same dim')
rotatedimage=rotImage(img,45,False)
plt.subplot(1,3,3)
plt.imshow(rotatedimage,cmap='gray')
plt.axis('off')
plt.title('45 Rotated Image with new dim')
plt.figure(figsize=[10,10])
plt.subplot(1,3,1)
plt.imshow(img,cmap='gray')
plt.axis('off')
plt.title('Original Image')
rotatedimage=rotImage(img,90,True)
plt.subplot(1,3,2)
plt.imshow(rotatedimage,cmap='gray')
plt.axis('off')
plt.title('90 Rotated Image with same dim')
rotatedimage=rotImage(img,90,False)
plt.subplot(1,3,3)
plt.imshow(rotatedimage,cmap='gray')
plt.axis('off')
plt.title('90 Rotated Image with new dim')

plt.figure(figsize=[10,10])
plt.subplot(1,3,1)
plt.imshow(img,cmap='gray')
plt.axis('off')
plt.title('Original Image')
rotatedimage=rotImage(img,180,True)
plt.subplot(1,3,2)
plt.imshow(rotatedimage,cmap='gray')
plt.axis('off')
plt.title('180 Rotated Image with same dim')
rotatedimage=rotImage(img,180,False)
plt.subplot(1,3,3)
plt.imshow(rotatedimage,cmap='gray')
plt.axis('off')
plt.title('180 Rotated Image with new dim')

plt.figure(figsize=[10,10])
plt.subplot(1,3,1)
plt.imshow(img,cmap='gray')
plt.axis('off')
plt.title('Original Image')
rotatedimage=rotImage(img,120,True)
plt.subplot(1,3,2)
plt.imshow(rotatedimage,cmap='gray')
plt.axis('off')
plt.title('120 Rotated Image with same dim')
rotatedimage=rotImage(img,120,False)
plt.subplot(1,3,3)
plt.imshow(rotatedimage,cmap='gray')
plt.axis('off')
plt.title('120 Rotated Image with new dim')
plt.show()
# Out:
# Rows, Columns, Channels: (480, 400)
